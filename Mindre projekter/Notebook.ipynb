# %% [markdown]
# ## <font> Her er der så meget tekst at jeg ikke har tid til at snakke med Damien og det er bare ærgeligt og sårn noget </font>

# %%
grid = [[0, 0, 0],
        [0, 0, 0],
        [0, 0, 0]]

# %%
n = 0
for y in range(len(grid)):
    for x in range(len(grid[y])):
        n += 1
        grid[y][x] = n

for i in range(len(grid)):
    print(grid[i])
# Out:
# [1, 2, 3]
# [4, 5, 6]
# [7, 8, 9]

# %%
from numpy import *
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
t =(1,2,3)

# %%
mean(t)
# Out:
# 2.0

# %%
max(t)
# Out:
# 3

# %%
x = array([[1, 2, 3], [4, 5, 6]])
x
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
print("x:\n{}".format(x))
# Out:
# x:
# [[1 2 3]
#  [4 5 6]]

# %%
x = linspace(-10, 10, 20)
y = x
plt.plot(x, y, marker="^")

# %%
x = [1, 2, 3, 4, 5]
y = [1, 2, 3, 4, 2]
plt.bar(x, y, alpha = 0.5, label = ("YOLO"))
# Out:
# <BarContainer object of 5 artists>

# %%
x = [1, 2, 3, 4]
y = [2, 2, 2, 2]
x1 = [1, 2, 3, 4]
y1 = [1, 3, 3, 7]
plt.bar(x, y, alpha = 0.5, label = ("Et æg"))
plt.bar(x1, y1, alpha = 0.5, label = ("Et krus"))
plt.title("Ja")
plt.xlabel("Word")
plt.ylabel("PowerPoint")
plt.legend()
